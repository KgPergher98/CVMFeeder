# %% [markdown]
# ## Extração de Documentos Estruturados e Não-Estruturados
# ### Kevin Pergher, 17 de Abril de 2024

# %%
from CVMFeeder import CVM
import warnings
import datetime

warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### get_cvm_categories()
# - Extrai as categorias de documentos CVM
#
# #### get_cvm_codes()
# - Extrai os códigos CVM, seu registro e o nome da empresa correspondente

# %%
categories = CVM().get_cvm_categories()
codigos = CVM().get_cvm_codes()

display(categories.head(2))
display(codigos.head(2))
# Out:
#      code                       description      doc_type
# 0  EST_-1  TODOS os Documentos Estruturados  estruturados
# 1   EST_3     ITR - Informações Trimestrais  estruturados
#       cvm                firm_name          status
# 0  900049  1461 INVESTIMENTOS S.A   REGISTRO ATIVO
# 1  252224          2W ECOBANK S.A.               -

# %% [markdown]
# Selecione o código de uma empresa de interesse, ex.: 3R Petróleo

# %%
rrrp = codigos[codigos.firm_name.str.startswith("3R PETRO")]
rrrp
# Out:
#       cvm                     firm_name          status
# 7  025291  3R PETROLEUM ÓLEO E GÁS S.A   REGISTRO ATIVO

# %% [markdown]
# #### cvm_history()
# - Extraia o histórico documentos contábeis estruturados da empresa usando os códigos estruturados
#
# #### get_reports()
# - Extraia os documentos contábeis estruturados

# %%
docs = CVM().cvm_history(cvm_code = rrrp.cvm.iloc[0], documents = categories.code[categories.doc_type == "estruturados"].tolist(), start_date = datetime.date(1995,12,31))
docs
# Out:
#   cod_cvm                       empresa  \
# 0  025291  3R PETROLEUM ÓLEO E GÁS S.A.
# 1  025291  3R PETROLEUM ÓLEO E GÁS S.A.
# 2  025291  3R PETROLEUM ÓLEO E GÁS S.A.
# 3  025291  3R PETROLEUM ÓLEO E GÁS S.A.
# 4  025291  3R PETROLEUM ÓLEO E GÁS S.A.
# 5  025291  3R PETROLEUM ÓLEO E GÁS S.A.
#
#                                       categoria tipo especie   ref_date  \
# 0                FRE - Formulário de Referência   -       -  2023-12-31
# 1  DFP - Demonstrações Financeiras Padronizadas   -       -  2023-12-31
# 2                    FCA - Formulário Cadastral   -       -  2024-01-01
# 3                 ITR - Informações Trimestrais   -       -  2023-09-30
# 4               Informe do Código de Governança   -       -  2023-12-31
# 5                FRE - Formulário de Referência   -       -  2022-01-01
#
#          data_entrega status version modalidade  \
# 0 2024-04-11 18:52:00  Ativo      23         RE
# 1 2024-03-07 01:18:00  Ativo       1         AP
# 2 2024-01-26 18:52:00  Ativo       1         AP
# 3 2023-11-08 20:35:00  Ativo       1         AP
# 4 2023-07-31 19:15:00  Ativo       1         AP
# 5 2023-05-05 19:08:00  Ativo      22         RE
#
#                                                acoes outros  \
# 0  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 1  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 2  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 3  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 4  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 5  <i class='fi-page-search' id='VisualizarDocume...    NaN
#
#                                             view_url numero_seq_documento  \
# 0  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...               135655
# 1  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...               134516
# 2  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...               133712
# 3  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...               131960
# 4  https://www.rad.cvm.gov.br/ENET/frmExibirCodig...               129589
# 5  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...               125846
#
#   codigo_tipo_instituicao numSequencia numVersao  \
# 0                       1       135655        23
# 1                       1       134516         1
# 2                       1       133712         1
# 3                       1       131960         1
# 4                     NaN       129589         1
# 5                       1       125846        22
#
#                      numProtocolo descTipo  \
# 0  025291FRE202320232300135655-68
# 1  025291DFP311220230100134516-78      DFP
# 2  025291FCA000020240100133712-70      FCA
# 3  025291ITR300920230100131960-75      ITR
# 4  025291CGVN20230101V01129589-88     CGVN
# 5  025291FRE202220222200125846-66
#
#                                                   id
# 0  025291_FRE_DR2023-12-31_DE2024-04-11_vs23_0252...
# 1  025291_DFP_DR2023-12-31_DE2024-03-07_vs1_02529...
# 2  025291_FCA_DR2024-01-01_DE2024-01-26_vs1_02529...
# 3  025291_ITR_DR2023-09-30_DE2023-11-08_vs1_02529...
# 4  025291_CGVN_DR2023-12-31_DE2023-07-31_vs1_0252...
# 5  025291_FRE_DR2022-01-01_DE2023-05-05_vs22_0252...

# %%
CVM().get_reports(docs = docs)
# Out:
#                     conta                                          descricao  \
# 0     001.000.000.000.000                                        ATIVO_TOTAL
# 1     001.001.000.000.000                                   ATIVO_CIRCULANTE
# 2     001.001.001.000.000                      CAIXA_E_EQUIVALENTES_DE_CAIXA
# 3     001.001.002.000.000                             APLICACOES_FINANCEIRAS
# 4     001.001.002.001.000  APLICACOES_FINANCEIRAS_AVALIADAS_A_VALOR_JUSTO...
# ...                   ...                                                ...
# 1194  007.008.004.001.000                      JUROS_SOBRE_O_CAPITAL_PROPRIO
# 1195  007.008.004.002.000                                         DIVIDENDOS
# 1196  007.008.004.003.000               LUCROS_RETIDOS_/_PREJUIZO_DO_PERIODO
# 1197  007.008.004.004.000         PART._NAO_CONTROLADORES_NOS_LUCROS_RETIDOS
# 1198  007.008.005.000.000                                             OUTROS
#
#      detail       valor    moeda                      structure cvm_code  \
# 0         -  20119858.0  (Mil)R$      BALANCO_PATRIMONIAL_ATIVO   025291
# 1         -   3965496.0  (Mil)R$      BALANCO_PATRIMONIAL_ATIVO   025291
# 2         -   1754106.0  (Mil)R$      BALANCO_PATRIMONIAL_ATIVO   025291
# 3         -    154559.0  (Mil)R$      BALANCO_PATRIMONIAL_ATIVO   025291
# 4         -         0.0  (Mil)R$      BALANCO_PATRIMONIAL_ATIVO   025291
# ...     ...         ...      ...                            ...      ...
# 1194      -         0.0  (Mil)R$  DEMONSTRACAO_VALOR_ADICIONADO   025291
# 1195      -         0.0  (Mil)R$  DEMONSTRACAO_VALOR_ADICIONADO   025291
# 1196      -     18038.0  (Mil)R$  DEMONSTRACAO_VALOR_ADICIONADO   025291
# 1197      -         0.0  (Mil)R$  DEMONSTRACAO_VALOR_ADICIONADO   025291
# 1198      -         0.0  (Mil)R$  DEMONSTRACAO_VALOR_ADICIONADO   025291
#
#      document    date_rel    date_ref versions  \
# 0         DFP  2023-12-31  2024-03-07        1
# 1         DFP  2023-12-31  2024-03-07        1
# 2         DFP  2023-12-31  2024-03-07        1
# 3         DFP  2023-12-31  2024-03-07        1
# 4         DFP  2023-12-31  2024-03-07        1
# ...       ...         ...         ...      ...
# 1194      ITR  2023-09-30  2023-11-08        1
# 1195      ITR  2023-09-30  2023-11-08        1
# 1196      ITR  2023-09-30  2023-11-08        1
# 1197      ITR  2023-09-30  2023-11-08        1
# 1198      ITR  2023-09-30  2023-11-08        1
#
#                                    protocol
# 0     025291DFP311220230100134516-78/134516
# 1     025291DFP311220230100134516-78/134516
# 2     025291DFP311220230100134516-78/134516
# 3     025291DFP311220230100134516-78/134516
# 4     025291DFP311220230100134516-78/134516
# ...                                     ...
# 1194  025291ITR300920230100131960-75/131960
# 1195  025291ITR300920230100131960-75/131960
# 1196  025291ITR300920230100131960-75/131960
# 1197  025291ITR300920230100131960-75/131960
# 1198  025291ITR300920230100131960-75/131960
#
# [1199 rows x 12 columns]

# %% [markdown]
# #### cvm_history()
# - Extraia o histórico documentos gerais da empresa usando os códigos estruturados
#
# #### get_documents()
# - Extraia os documentos não-estruturados

# %%
docs = CVM().cvm_history(cvm_code = rrrp.cvm.iloc[0], documents = categories.code[categories.doc_type == "eventuais"].tolist(), start_date = datetime.date(2024,4,1))
docs
# Out:
#   cod_cvm                      empresa  \
# 8  025291  3R PETROLEUM ÓLEO E GÁS S.A
# 7  025291  3R PETROLEUM ÓLEO E GÁS S.A
# 6  025291  3R PETROLEUM ÓLEO E GÁS S.A
# 5  025291  3R PETROLEUM ÓLEO E GÁS S.A
# 4  025291  3R PETROLEUM ÓLEO E GÁS S.A
# 3  025291  3R PETROLEUM ÓLEO E GÁS S.A
# 2  025291  3R PETROLEUM ÓLEO E GÁS S.A
# 1  025291  3R PETROLEUM ÓLEO E GÁS S.A
# 0  025291  3R PETROLEUM ÓLEO E GÁS S.A
#
#                                   categoria  \
# 8  Valores Mobiliários Negociados e Detidos
# 7                     Comunicado ao Mercado
# 6                  Reunião da Administração
# 5                            Fato Relevante
# 4                     Comunicado ao Mercado
# 3                  Reunião da Administração
# 2              Regimento interno de Comitês
# 1                   Política de Remuneração
# 0              Regimento interno de Comitês
#
#                                                 tipo  \
# 8                                Posição Consolidada
# 7  Outros Comunicados Não Considerados Fatos Rele...
# 6                          Conselho de Administração
# 5                                                 -
# 4  Aquisição/Alienação de Participação Acionária ...
# 3                          Conselho de Administração
# 2                                                 -
# 1                                                 -
# 0                                                 -
#
#                                              especie   ref_date  \
# 8                                                 -  2024-03-01
# 7                  Dados de Produção - Março 2024 -  2024-04-10
# 6  Deliberar sobre a assinatura de MOU junto à En... 2024-04-09
# 5  Assinatura de MOU junto à Enauta e à Maha Offs... 2024-04-09
# 4  Declaração de Alienação de Participação Acioná... 2024-04-02
# 3  Eleição de Diretor(es); Eleição Presidente do ... 2024-03-21
# 2           Regimento Interno Comitê de Auditoria -  2024-03-21
# 1                                                 -  2024-03-21
# 0                  https://ri.3rpetroleum.com.br/ -  2024-03-21
#
#          data_entrega     status version modalidade  \
# 8 2024-04-10 19:15:00      Ativo       1         AP
# 7 2024-04-10 01:20:00      Ativo       1         AP
# 6 2024-04-10 00:22:00      Ativo       1         AP
# 5 2024-04-09 23:58:00      Ativo       1         AP
# 4 2024-04-02 22:38:00      Ativo       1         AP
# 3 2024-04-01 20:33:00      Ativo       1         AP
# 2 2024-04-01 19:52:00      Ativo       1         AP
# 1 2024-04-01 19:44:00      Ativo       1         AP
# 0 2024-04-01 19:39:00  Cancelado       1         AP
#
#                                                acoes outros  \
# 8  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 7  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 6  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 5  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 4  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 3  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 2  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 1  <i class='fi-page-search' id='VisualizarDocume...    NaN
# 0  <i class='fi-page-search' id='VisualizarDocume...    NaN
#
#                                             view_url numero_seq_documento  \
# 8  https://www.rad.cvm.gov.br/ENET/frmExibirArqui...                  NaN
# 7  https://www.rad.cvm.gov.br/ENET/frmExibirArqui...                  NaN
# 6  https://www.rad.cvm.gov.br/ENET/frmExibirArqui...                  NaN
# 5  https://www.rad.cvm.gov.br/ENET/frmExibirArqui...                  NaN
# 4  https://www.rad.cvm.gov.br/ENET/frmExibirArqui...                  NaN
# 3  https://www.rad.cvm.gov.br/ENET/frmExibirArqui...                  NaN
# 2  https://www.rad.cvm.gov.br/ENET/frmExibirArqui...                  NaN
# 1  https://www.rad.cvm.gov.br/ENET/frmExibirArqui...                  NaN
# 0  https://www.rad.cvm.gov.br/ENET/frmExibirArqui...                  NaN
#
#   codigo_tipo_instituicao numSequencia numVersao numProtocolo descTipo  \
# 8                     NaN       745471         1      1220745      IPE
# 7                     NaN       744901         1      1220175      IPE
# 6                     NaN       744888         1      1220162      IPE
# 5                     NaN       744879         1      1220153      IPE
# 4                     NaN       741872         1      1217146      IPE
# 3                     NaN       741170         1      1216444      IPE
# 2                     NaN       741137         1      1216411      IPE
# 1                     NaN       741130         1      1216404      IPE
# 0                     NaN       741128         1      1216402      IPE
#
#                                                   id
# 8  025291_IPE_DR2024-03-01_DE2024-04-10_vs1_12207...
# 7  025291_IPE_DR2024-04-10_DE2024-04-10_vs1_12201...
# 6  025291_IPE_DR2024-04-09_DE2024-04-10_vs1_12201...
# 5  025291_IPE_DR2024-04-09_DE2024-04-09_vs1_12201...
# 4  025291_IPE_DR2024-04-02_DE2024-04-02_vs1_12171...
# 3  025291_IPE_DR2024-03-21_DE2024-04-01_vs1_12164...
# 2  025291_IPE_DR2024-03-21_DE2024-04-01_vs1_12164...
# 1  025291_IPE_DR2024-03-21_DE2024-04-01_vs1_12164...
# 0  025291_IPE_DR2024-03-21_DE2024-04-01_vs1_12164...

# %%
CVM().get_documents(docs)
# Out:
#                                                 file cvm_code document  \
# 0  b'%PDF-1.4\n%\xe2\xe3\xcf\xd3\n3 0 obj\n<</Len...   025291      IPE
# 1  b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n...   025291      IPE
# 2  b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n...   025291      IPE
# 3  b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n...   025291      IPE
# 4  b'%PDF-1.7\r%\xe2\xe3\xcf\xd3\r\n108 0 obj\r<<...   025291      IPE
# 5  b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n...   025291      IPE
# 6  b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n...   025291      IPE
# 7  b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n...   025291      IPE
# 8  b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n...   025291      IPE
#
#      date_rel    date_ref versions        protocol
# 0  2024-03-01  2024-04-10        1  1220745/745471
# 1  2024-04-10  2024-04-10        1  1220175/744901
# 2  2024-04-09  2024-04-10        1  1220162/744888
# 3  2024-04-09  2024-04-09        1  1220153/744879
# 4  2024-04-02  2024-04-02        1  1217146/741872
# 5  2024-03-21  2024-04-01        1  1216444/741170
# 6  2024-03-21  2024-04-01        1  1216411/741137
# 7  2024-03-21  2024-04-01        1  1216404/741130
# 8  2024-03-21  2024-04-01        1  1216402/741128
